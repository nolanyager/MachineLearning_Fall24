# %% [markdown]
# K-Means in Class Work

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

samples_per_cluster = 100
n_clusters = 3
dim = 2

cluster_means = [
    [0, 0],
    [3, 3],
    [0, 3]
]

cluster_sd = 0.5

X = np.zeros((samples_per_cluster * n_clusters, dim))

for i, mean in enumerate(cluster_means):
    X[i * samples_per_cluster:(i + 1) * samples_per_cluster] = np.random.normal(mean, cluster_sd, (samples_per_cluster, dim))

plt.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# Work starts here:

# %%
# We're going to pick K=3, for fairly obvious reasons

# K means class: 
class K_means: 
    def __init__(self, k=3, tol=0.001, max_iter=250):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

# Congrats nolan you picked your values for k wow great

# Ok now we're gonna work on the fit
def fit(self,data):

    self.centroids = {}

    for i in range(self.k): 
        self.centroids[i] = data[i]
        
    for i in range(self.max_iter):
        self.classifications = {}
    
    for featureset in data: 
        distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        self.classifications[classification].append(featureset)
    
    prev_centroids = dict(self.centroids)
    
    for classification in self.classifications:
        self.centroids[classification] = np.average(self.classifications[classifcation],axis=0)

# %%
# Have we optimized? 
##### CONTINUE HERE
